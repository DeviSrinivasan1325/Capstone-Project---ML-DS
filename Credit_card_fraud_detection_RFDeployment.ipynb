# %%
import pickle

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
loaded_model = pickle.load(open("Finalized_credit_card_fraud_detection_model_GridRandomForest.pkl", 'rb'))

prediction = loaded_model.predict([[
    50000, 5, 1, 1,80, 5, 50,
    0, 1, 0, 0
]])

print("Fraud Prediction:", prediction[0])
# Out:
# Fraud Prediction: 0

# %%
#crossing checking model imported
type(loaded_model)
# Out:
# sklearn.pipeline.Pipeline
